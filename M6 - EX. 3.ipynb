# %% [markdown]
# # Módulo 6 tarefa 3
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esse arquivo.

# %%
# importação de pacotes
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# carregando base

roraima = pd.read_csv('RO_2019.csv')

roraima
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0           1  2679477.0      110001        1        19        5.0
# 1           1  2679477.0      110001        1        29        2.0
# 2           1  2679477.0      110001        1        37        9.0
# 3           1  2516500.0      110001        1        30        5.0
# 4           1  2516500.0      110001        1        30        2.0
# ...       ...        ...         ...      ...       ...        ...
# 27023       1  2604388.0      510340        1        32        2.0
# 27024       1  2752654.0      510675        1        19        1.0
# 27025       1  9659366.0      510787        1        24        2.0
# 27026       1  9659366.0      510787        1        21        2.0
# 27027       1  2795655.0      510792        1        18        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0          8 a 11 anos         NaN         0.0         0.0  ...           5
# ...

# %% [markdown]
# #### 2) Categorize a variável APGAR5 conforme as seguintes quebras:
#
# - 0 a 3: 'asfixia grave'
# - 4 a 5: 'asfixia moderada'
# - 6 a 7: 'asfixia leve'
# - 8 a 10: 'normal'

# %%
roraima['APGAR5']
# Out:
# 0        10.0
# 1         9.0
# 2        10.0
# 3        10.0
# 4        10.0
#          ...
# 27023     9.0
# 27024     9.0
# 27025    10.0
# 27026     9.0
# 27027     8.0
# Name: APGAR5, Length: 27028, dtype: float64

# %%
roraima.loc[roraima['APGAR5']<3, 'ASFIXIA'] = 'asfixia grave'
roraima.loc[(roraima['APGAR5']>= 4) & (roraima['APGAR5']<=5), 'ASFIXIA' ] = 'asfixia moderada'
roraima.loc[(roraima['APGAR5']>= 6) & (roraima['APGAR5']<=7), 'ASFIXIA'] = 'asfixia leve'
roraima.loc[(roraima['APGAR5']>= 8) & (roraima['APGAR5']<=10), 'ASFIXIA'] = 'normal'

roraima['ASFIXIA']
# Out:
# 0        normal
# 1        normal
# 2        normal
# 3        normal
# 4        normal
#           ...
# 27023    normal
# 27024    normal
# 27025    normal
# 27026    normal
# 27027    normal
# Name: ASFIXIA, Length: 27028, dtype: object

# %% [markdown]
# #### 3) Monte um gráfico comparando a distribuição de APGAR5 por sexo para cada grupo de tempo de gestação (GESTACAO).

# %%
sns.catplot(x='GESTACAO', y='APGAR5'
            , hue = 'SEXO' 
            , kind='bar'
            , estimator = sum 
            , data=roraima
           , ci = None 
           )
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '37 a 41 semanas'),
#   Text(1, 0, '42 semanas e mais'),
#   Text(2, 0, '32 a 36 semanas'),
#   Text(3, 0, '22 a 27 semanas'),
#   Text(4, 0, '28 a 31 semanas'),
#   Text(5, 0, 'Menos de 22 semanas')])

# %% [markdown]
# ####  4) Monte uma tabela cruzada com APGAR5 nas colunas e GESTACAO nas linhas

# %%
freq = pd.crosstab(roraima['APGAR5'], roraima['GESTACAO'])
freq
# Out:
# GESTACAO  22 a 27 semanas  28 a 31 semanas  32 a 36 semanas  37 a 41 semanas  \
# APGAR5
# 0.0                     7                0                2                5
# 1.0                     0                0                2               20
# 2.0                     8                2                2                3
# 3.0                     6                1                2                5
# 4.0                     1                5                8                7
# 5.0                     0                7               11               21
# 6.0                     2                7               17               45
# 7.0                    10               11               56              151
# 8.0                    24               61              362             1417
# 9.0                    19               55             1307            13565
# 10.0                    8               13              465             7284
#
# ...

# %% [markdown]
# ####  5) Da tabela cruzada do intem anterior, calcule os percentuais de linha. Ou seja, a distribuição da variável APGAR5 para cada classe de GESTACAO dado.

# %%
freq_pctlin = freq.div(freq.sum(axis = 1), axis = 0)
freq_pctlin
# Out:
# GESTACAO  22 a 27 semanas  28 a 31 semanas  32 a 36 semanas  37 a 41 semanas  \
# APGAR5
# 0.0              0.437500         0.000000         0.125000         0.312500
# 1.0              0.000000         0.000000         0.090909         0.909091
# 2.0              0.500000         0.125000         0.125000         0.187500
# 3.0              0.428571         0.071429         0.142857         0.357143
# 4.0              0.047619         0.238095         0.380952         0.333333
# 5.0              0.000000         0.175000         0.275000         0.525000
# 6.0              0.027778         0.097222         0.236111         0.625000
# 7.0              0.042735         0.047009         0.239316         0.645299
# 8.0              0.012579         0.031971         0.189727         0.742662
# 9.0              0.001236         0.003578         0.085025         0.882449
# 10.0             0.001001         0.001626         0.058169         0.911183
#
# ...

# %% [markdown]
# ####  6) Os médicos costumam classificar parto prematuro quando a gestação tem menos que 37 semanas. Faça um gráfico de barras da tabela cruzada acima e conclua se você acha que este conjunto de dados corrobora ou não com a afirmação dos médicos.

# %%
freq_pctlin.plot.bar()
# Out:
# <AxesSubplot:xlabel='APGAR5'>

# %% [markdown]
# Observa-se que quando menor o APGAR5 a quantidade de prematuros é maior.

# %% [markdown]
# #### 7) Veja se há relação entre APGAR5 e o peso do bebê. Isso pode ser feito de diversas formas. Fique à vontade para escolher a melhor maneira na sua opinião, ou até testar mais de um dos gráficos que vimos. Fique à vontade também para consultar a documentação e utilizar algum outro recurso se achar conveniente.

# %%
sns.scatterplot(x = 'PESO'
                , y = 'APGAR5'
                , data = roraima
                , alpha = .5
               )
# Out:
# <AxesSubplot:xlabel='PESO', ylabel='APGAR5'>

# %%
sns.catplot(x='APGAR5', y='PESO'
          #  , hue = 'fumante'quebra fumante e não fumante para cada dia da semana
            , kind='bar'
            , estimator = sum # coloca a soma no eixo y
            , data = roraima
           , ci = None #tiramos o intervalo de confiança
           )

# %%
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...
