# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'items': [{'id_pleito': 5843,
#    'tipo_interessado': 'Município',
#    'interessado': 'Maricá',
#    'cod_ibge': 3302700,
#    'uf': 'RJ',
#    'num_pvl': None,
#    'status': 'Arquivado',
#    'num_processo': '17944.000212/2010-10',
#    'data_protocolo': '2010-11-30T02:00:00Z',
#    'tipo_operacao': 'Operação contratual interna',
#    'finalidade': 'PAC - Pró-Moradia - 2009',
#    'tipo_credor': 'Instituição Financeira Nacional',
#    'credor': 'Caixa Econômica Federal',
#    'moeda': 'Real',
#    'valor': 51016091.98,
#    'pvl_assoc_divida': 0,
#    'pvl_contradado_credor': 0,
#    'data_status': '28/12/2010'},
#   {'id_pleito': 4924,
#    'tipo_interessado': 'Município',
#    'interessado': 'Rio de Janeiro',
#    'cod_ibge': 3304557,
#    'uf': 'RJ',
#    'num_pvl': None,
#    'status': 'Arquivado',
#    'num_processo': '10951.000224/2000-63',
#    'data_protocolo': '2005-12-27T02:00:00Z',
#    'tipo_operacao': 'Operação contratual externa (com garantia da União)',
# ...

# %%
data_json = r.json()
print(data_json)
# Out:
# {'items': [{'id_pleito': 5843, 'tipo_interessado': 'Município', 'interessado': 'Maricá', 'cod_ibge': 3302700, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000212/2010-10', 'data_protocolo': '2010-11-30T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC - Pró-Moradia - 2009', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 51016091.98, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '28/12/2010'}, {'id_pleito': 4924, 'tipo_interessado': 'Município', 'interessado': 'Rio de Janeiro', 'cod_ibge': 3304557, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '10951.000224/2000-63', 'data_protocolo': '2005-12-27T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Preservação e recuperação ambiental', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Japan Bank for Internatio
# ...

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 5843, 'tipo_interessado': 'Município', 'interessado': 'Maricá', 'cod_ibge': 3302700, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.000212/2010-10', 'data_protocolo': '2010-11-30T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC - Pró-Moradia - 2009', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 51016091.98, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '28/12/2010'}, {'id_pleito': 4924, 'tipo_interessado': 'Município', 'interessado': 'Rio de Janeiro', 'cod_ibge': 3304557, 'uf': 'RJ', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '10951.000224/2000-63', 'data_protocolo': '2005-12-27T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Preservação e recuperação ambiental', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Japan Bank for International Cooper
# ...

# %%
Data_Rio = pd.DataFrame(data_json['items'])
Data_Rio.head()
# Out:
#    id_pleito tipo_interessado         interessado  cod_ibge  uf num_pvl  \
# 0       5843        Município              Maricá   3302700  RJ    None
# 1       4924        Município      Rio de Janeiro   3304557  RJ    None
# 2       5864        Município         Duas Barras   3301603  RJ    None
# 3       5328        Município  São João de Meriti   3305109  RJ    None
# 4      11419        Município      Rio de Janeiro   3304557  RJ    None
#
#       status          num_processo        data_protocolo  \
# 0  Arquivado  17944.000212/2010-10  2010-11-30T02:00:00Z
# 1  Arquivado  10951.000224/2000-63  2005-12-27T02:00:00Z
# 2  Arquivado  17944.000218/2008-72  2008-04-14T03:00:00Z
# 3  Arquivado  17944.000088/2007-97  2007-01-17T02:00:00Z
# 4   Deferido  17944.001440/2008-92  2008-06-13T03:00:00Z
#
#                                        tipo_operacao  \
# 0                        Operação contratual interna
# 1  Operação contratual externa (com garantia da U...
# ...

# %%
# 2) Seu código aqui
Data_Rio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              235 non-null    int64
#  1   tipo_interessado       235 non-null    object
#  2   interessado            235 non-null    object
#  3   cod_ibge               235 non-null    int64
#  4   uf                     235 non-null    object
#  5   num_pvl                58 non-null     object
#  6   status                 235 non-null    object
#  7   num_processo           218 non-null    object
#  8   data_protocolo         218 non-null    object
#  9   tipo_operacao          235 non-null    object
#  10  finalidade             235 non-null    object
#  11  tipo_credor            235 non-null    object
#  12  credor                 235 non-null    object
#  13  moeda                  235 non-null    object
# ...

# %%
Data_Rio['status'].value_counts()
# Out:
# Deferido                                                 93
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        16
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           4
# Em retificação pelo interessado (PVL-IF)                  1
# Pendente de regularização                                 1
# Name: status, dtype: int64

# %%
x = Data_Rio['interessado'].value_counts()
x
# Out:
# Rio de Janeiro           41
# Resende                  15
# Nova Iguaçu              14
# Duque de Caxias          11
# Niterói                   9
#                          ..
# Porciúncula               1
# Rio das Flores            1
# Varre-Sai                 1
# Campos dos Goytacazes     1
# Silva Jardim              1
# Name: interessado, Length: 61, dtype: int64

# %%
y = solic_mais_frequente = (Data_Rio['interessado'] == 'Rio de Janeiro') | (Data_Rio['interessado'] == 'Resende') | (Data_Rio['interessado'] == 'Nova Iguaçu')
y
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 230     True
# 231    False
# 232    False
# 233     True
# 234     True
# Name: interessado, Length: 235, dtype: bool

# %%
Data_Rio[solic_mais_frequente]['status'].value_counts()
# Out:
# Deferido                                                 40
# Arquivado                                                10
# Deferido (PVL-IF)                                         6
# Regularizado                                              5
# Arquivado por decurso de prazo                            5
# Encaminhado à PGFN com manifestação técnica favorável     4
# Name: status, dtype: int64

# %%
# 3) Seu código aqui

data_status = Data_Rio['data_status']
data_status
# Out:
# 0      28/12/2010
# 1      17/08/2006
# 2      06/05/2008
# 3      28/05/2007
# 4      30/06/2008
#           ...
# 230    25/05/2007
# 231    17/10/2019
# 232    22/10/2013
# 233    29/11/2018
# 234    13/07/2010
# Name: data_status, Length: 235, dtype: object

# %%
ano = data_status.str.slice(6)
ano
# Out:
# 0      2010
# 1      2006
# 2      2008
# 3      2007
# 4      2008
#        ...
# 230    2007
# 231    2019
# 232    2013
# 233    2018
# 234    2010
# Name: data_status, Length: 235, dtype: object

# %%
ano.value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2013    15
# 2020    15
# 2022    14
# 2012    13
# 2011    10
# 2009     9
# 2015     9
# 2021     5
# 2017     5
# 2006     4
# 2002     4
# 2018     4
# 2016     4
# 2004     1
# 2003     1
# Name: data_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def Data_UF (uf:str):
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=UF&tipo_interessado=Munic%C3%ADpio'
    url = url.replace('UF',uf)
    r = requests.get(url)
    r.json()
    Data_json = r.json()
    Data_json = pd.DataFrame(Data_json['items'])

    return Data_json

# %%
Data_UF ('GO')
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 0       19060           Estado       Goiás        52  GO
# 1       24689           Estado       Goiás        52  GO
# 2        7091           Estado       Goiás        52  GO
# 3       12216           Estado       Goiás        52  GO
# 4       10948           Estado       Goiás        52  GO
# 5       24752           Estado       Goiás        52  GO
# 6       10297           Estado       Goiás        52  GO
# 7       13287           Estado       Goiás        52  GO
# 8        7912           Estado       Goiás        52  GO
# 9        5176           Estado       Goiás        52  GO
# 10      24742           Estado       Goiás        52  GO
# 11      10036           Estado       Goiás        52  GO
# 12      13462           Estado       Goiás        52  GO
# 13      11431           Estado       Goiás        52  GO
# 14      13438           Estado       Goiás        52  GO
# ...

# %%
# 2) Seu código aqui
Data_UF ('MG')
# Out:
#       id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0          5507        Município  Pedra do Indaiá   3148905  MG
# 1          5521        Município          Planura   3151602  MG
# 2          5606        Município         Contagem   3118601  MG
# 3          5613        Município          Camacho   3110400  MG
# 4          5619        Município  Icaraí de Minas   3130051  MG
# ...         ...              ...              ...       ...  ..
# 4268      34066        Município        Arceburgo   3104106  MG
# 4269      34074        Município           Arinos   3104502  MG
# 4270       5491        Município       Abre Campo   3100302  MG
# 4271      21653        Município          Guaxupé   3128709  MG
# 4272       7951        Município         Argirita   3104403  MG
#
#                    num_pvl                          status  \
# 0                     None                        Deferido
# 1                     None                        Deferido
# ...

# %%
Data_MG = Data_UF ('MG')
s = (Data_MG['status'] == 'Arquivado por decurso de prazo')
Data_MG[s]['status'].count()
# Out:
# 295

# %% [markdown]
# Podem ser feitas 295 consultas com o status "Arquivado por decurso de prazo"

# %%
# 3) Seu código aqui
Data_UF('BA')
# Out:
#      id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0         5954        Município  Oliveira dos Brejinhos   2923209  BA
# 1         5972        Município                 Varzedo   2933174  BA
# 2         6096        Município                  Mucuri   2922003  BA
# 3         5015        Município              Alagoinhas   2900702  BA
# 4         5692        Município          Cruz Das Almas   2909802  BA
# ..         ...              ...                     ...       ...  ..
# 876      18350        Município  Luís Eduardo Magalhães   2919553  BA
# 877      31240        Município                 Boninal   2904001  BA
# 878      18560        Município        Amélia Rodrigues   2901106  BA
# 879      18580        Município    Conceição do Almeida   2908309  BA
# 880      18590        Município               Itaparica   2916104  BA
#
#                   num_pvl                          status  \
# 0                    None                        Deferido
# ...

# %%
Data_BA = Data_UF('BA')
z = (Data_BA['status'] == 'Deferido')
Data_BA[z]['interessado'].value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Lauro de Freitas          10
# Camaçari                  10
# Barreiras                  9
#                           ..
# Mansidão                   1
# Nova Canaã                 1
# Mutuípe                    1
# Castro Alves               1
# Amélia Rodrigues           1
# Name: interessado, Length: 175, dtype: int64

# %% [markdown]
# O município de Luís Eduardo Magalhães teve mais solicitações deferidas no estado da Bahia.

# %%
# 4) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
r = requests.get(url)
r.json()
Data_json = r.json()
Data_json = pd.DataFrame(Data_json['items'])
Data_json
# Out:
#     id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0       10431           Estado       Bahia        29  BA    None
# 1       18559           Estado       Bahia        29  BA    None
# 2       18567           Estado       Bahia        29  BA    None
# 3       18571           Estado       Bahia        29  BA    None
# 4       18531           Estado       Bahia        29  BA    None
# ..        ...              ...         ...       ...  ..     ...
# 77      18356           Estado       Bahia        29  BA    None
# 78      18551           Estado       Bahia        29  BA    None
# 79      18575           Estado       Bahia        29  BA    None
# 80      18579           Estado       Bahia        29  BA    None
# 81      18587           Estado       Bahia        29  BA    None
#
#                                                status          num_processo  \
# 0   Encaminhado à PGFN com manifestação técnica fa...  17944.001198/2012-33
# ...

# %%
Data_json.to_csv('Dados_Bahia_Estado.csv')
